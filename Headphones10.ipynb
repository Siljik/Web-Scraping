# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the Flipkart headphones page
url = "https://www.flipkart.com/search?q=headphones"

# Send a GET request to the URL
response = requests.get(url)

# Parse the HTML content of the page
soup = BeautifulSoup(response.content, 'html.parser')

# Lists to store data
headphone_titles = []
headphone_prices = []

# Find all the product containers on the page
product_containers = soup.find_all("div", class_="_4ddWXP")

# Loop through each product container
for container in product_containers:
    # Extract the title of the headphone
    title = container.find("a", class_="s1Q9rs").text
    headphone_titles.append(title)

    # Extract the price of the headphone
    price = container.find("div", class_="_30jeq3").text
    headphone_prices.append(price)

# Create a DataFrame using pandas
data = {'Title': headphone_titles, 'Price': headphone_prices}
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
output_file = 'flipkart_headphones.csv'
df.to_csv(output_file, index=False)

print(f"Data saved to {output_file}")
# Out:
# Data saved to flipkart_headphones.csv
